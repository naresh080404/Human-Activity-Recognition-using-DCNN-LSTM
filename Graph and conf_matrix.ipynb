# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

y_train = pd.read_csv("/content/drive/MyDrive/UCI HAR Dataset/train/y_train.txt", delim_whitespace=True, header=None).values.ravel()
y_test = pd.read_csv("/content/drive/MyDrive/UCI HAR Dataset/test/y_test.txt", delim_whitespace=True, header=None).values.ravel()



final_df1 = pd.read_csv(r"/content/geneticalgooutput (1).csv")
final_df1 = final_df1.iloc[:, :89]
y_combined_df = pd.concat([pd.Series(y_train), pd.Series(y_test)])


X = final_df1
y = y_combined_df

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_final = X_scaled[:]

selected_features_aco=[48,
 10,
 48,
 18,
 63,
 20,
 61,
 10,
 76,
 40,
 5,
 76,
 56,
 27,
 6,
 54,
 79,
 2,
 59,
 5,
 36,
 51,
 56,
 47,
 15,
 8,
 17,
 59,
 60,
 30,
 62,
 7,
 14,
 45,
 19,
 82,
 50,
 56,
 0,
 11,
 67,
 68,
 13,
 48,
 30,
 25,
 27]
X_final = X_scaled[:,selected_features_aco]
X_final=pd.DataFrame(X_final)
X_final.head(10299)
selected_features=[1, 3, 8, 9, 10, 13, 15, 18, 19, 21, 22, 26, 32, 33, 34, 37, 38, 40, 42, 45]
X_final_nparray=np.array(X_final)
X_temparr=X_final_nparray[:,selected_features]
X_temp=pd.DataFrame(X_final_nparray[:,selected_features])
X_temp.head(10299)
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.868773 -0.771213 -2.042964  1.485495 -0.945431 -3.891042 -0.371484
# 1     -0.884263 -0.770620 -1.405613  1.269000 -0.929817 -1.772857 -0.349378
# 2     -0.876139 -0.769600 -0.967963  1.347501 -0.913598 -0.788590 -0.349378
# 3     -0.876139 -0.770205  0.358887  1.077732 -0.946015 -0.136505 -0.366495
# 4     -0.883152 -0.771156  0.935553  1.321739 -0.940846 -0.970273 -0.367818
# ...         ...       ...       ...       ...       ...       ...       ...
# 10294  1.210539  0.384289  0.735092 -0.332102  0.738886  0.043661 -0.767326
# 10295  1.210539  0.856951  0.035068 -0.188236  1.076214 -0.522792 -0.756616
# 10296  0.880306  0.669623 -0.373917  0.044241  0.935694 -1.030175 -0.756616
# 10297  0.880306  0.162166  0.050097  0.054367  0.560590 -1.325299 -0.694372
# 10298  0.659399  0.226944  0.382083 -0.122185  0.629605 -0.653513 -0.689311
#
#              7         8         9         10        11        12        13  \
# 0     -0.499695 -0.945431 -0.411666 -0.706356 -0.706303  0.874510 -0.320117
# 1     -0.506746 -0.929817 -0.411876 -0.726777 -0.706492  0.874510 -0.410863
# 2     -0.514226 -0.913598 -0.418336 -0.773143 -0.706402  0.864346 -0.450946
# 3     -0.515988 -0.946015 -0.418336 -0.769766 -0.706428  0.864346 -0.316416
# 4     -0.520570 -0.940846 -0.426723 -0.770272 -0.706489  0.866851 -0.395043
# ...         ...       ...       ...       ...       ...       ...       ...
# 10294 -0.294744  0.738886 -0.731239  0.748778  0.326047 -0.593473  0.398894
# 10295 -0.302345  1.076214 -0.731239  0.714089  0.281338 -1.213350  0.291804
# 10296 -0.306312  0.935694 -0.718627  0.708206  0.212658 -1.213350  0.247496
# 10297 -0.286905  0.560590 -0.715810  0.681904  0.227469 -0.336173 -0.091354
# 10298 -0.284771  0.629605 -0.715810  0.690000  0.219802 -0.653277 -0.119239
#
#              14        15        16        17        18        19
# 0     -0.679412 -0.706356 -1.731883  0.230048  0.918871 -1.206949
# 1     -0.697827 -0.726777 -1.731546 -0.615071  0.908664 -1.122341
# 2     -0.702993 -0.773143 -1.731210 -2.456876  0.892681 -1.122341
# 3     -0.703159 -0.769766 -1.730874 -2.228321  0.892681 -2.048469
# 4     -0.704387 -0.770272 -1.730537 -1.305973  0.908067 -1.639764
# ...         ...       ...       ...       ...       ...       ...
# 10294  0.647372  0.748778  1.730537 -0.127378 -0.477836  0.984414
# 10295  0.710708  0.714089  1.730874 -0.007074 -0.310328  0.735797
# 10296  0.531317  0.708206  1.731210  0.080272 -0.344355  0.884723
# 10297  0.673244  0.681904  1.731546 -0.539951 -0.470604  1.386772
# 10298  0.829370  0.690000  1.731883 -0.327348 -0.794923  1.137309
#
# [10299 rows x 20 columns]

# %%
import matplotlib.pyplot as plt


import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

label_encoder = LabelEncoder()
y_combined_encoded = label_encoder.fit_transform(y)

X_tensor = torch.FloatTensor(X_temparr)
y_tensor = torch.LongTensor(y_combined_encoded)

device = torch.device("cpu")
X_tensor, y_tensor = X_tensor.to(device), y_tensor.to(device)

X_train, X_test, y_train, y_test = train_test_split(X_tensor, y_tensor, test_size=0.2, random_state=42)

train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

class HybridModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(HybridModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=3)
        self.conv2 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.lstm1 = nn.LSTM(input_size=128, hidden_size=hidden_size, batch_first=True, dropout=0.5)
        self.lstm2 = nn.LSTM(input_size=hidden_size, hidden_size=hidden_size, batch_first=True, dropout=0.5)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x = torch.relu(self.conv1(x.unsqueeze(1)))
        x = torch.relu(self.conv2(x))
        x = self.pool(x)
        x = x.permute(0, 2, 1)
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x = x[:, -1, :]
        x = self.fc(x)
        return x

model1 = HybridModel(input_size=20, hidden_size=64, num_classes=len(label_encoder.classes_)).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model1.parameters(), lr=0.001)
# Lists to store training loss, training accuracy, and test accuracy
train_losses = []
train_accuracies = []
test_accuracies = []

num_epochs = 200
for epoch in range(num_epochs):
    model1.train()
    total_loss = 0.0
    correct_train_predictions = 0
    total_train_samples = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model1(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train_samples += labels.size(0)
        correct_train_predictions += (predicted == labels).sum().item()

    train_epoch_loss = total_loss / len(train_loader)
    train_epoch_accuracy = correct_train_predictions / total_train_samples

    # Store training loss and accuracy
    train_losses.append(train_epoch_loss)
    train_accuracies.append(train_epoch_accuracy)

    model1.eval()
    correct_test_predictions = 0
    total_test_samples = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model1(inputs)
            _, preds = torch.max(outputs, 1)
            total_test_samples += labels.size(0)
            correct_test_predictions += (preds == labels).sum().item()

    test_epoch_accuracy = correct_test_predictions / total_test_samples

    # Store test accuracy
    test_accuracies.append(test_epoch_accuracy)

    print(f"Epoch [{epoch + 1}/{num_epochs}], "
          f"Train Loss: {train_epoch_loss:.4f}, Train Accuracy: {train_epoch_accuracy:.4f}, "
          f"Test Accuracy: {test_epoch_accuracy:.4f}")

# Plotting
plt.figure(figsize=(12, 5))

# Plot training loss
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()

# Plot training and test accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy')
plt.plot(range(1, num_epochs + 1), test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
#
# Epoch [99/200], Train Loss: 0.0121, Train Accuracy: 0.9962, Test Accuracy: 0.9694
# Epoch [100/200], Train Loss: 0.0173, Train Accuracy: 0.9939, Test Accuracy: 0.9529
# Epoch [101/200], Train Loss: 0.0253, Train Accuracy: 0.9911, Test Accuracy: 0.9563
# Epoch [102/200], Train Loss: 0.0182, Train Accuracy: 0.9931, Test Accuracy: 0.9539
# Epoch [103/200], Train Loss: 0.0104, Train Accuracy: 0.9966, Test Accuracy: 0.9714
# Epoch [104/200], Train Loss: 0.0014, Train Accuracy: 0.9998, Test Accuracy: 0.9694
# Epoch [105/200], Train Loss: 0.0007, Train Accuracy: 1.0000, Test Accuracy: 0.9714
# Epoch [106/200], Train Loss: 0.0005, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [107/200], Train Loss: 0.0004, Train Accuracy: 1.0000, Test Accuracy: 0.9704
# Epoch [108/200], Train Loss: 0.0003, Train Accuracy: 1.0000, Test Accuracy: 0.9709
# Epoch [109/200], Train Loss: 0.0003, Train Accuracy: 1.0000, Test Accuracy: 0.9709
# Epoch [110/200], Train Loss: 0.0002, Train Accuracy: 1.0000, Test Accuracy: 0.9709
# Epoch [111/200], Train Loss: 0.0002, Train Accuracy: 1.0000, Test Accuracy: 0.9709
# Epoch [112/200], Train Loss: 0.0002, Train Accuracy: 1.0000, Test Accuracy: 0.9709
# Epoch [113/200], Train Loss: 0.0002, Train Accuracy: 1.0000, Test Accuracy: 0.9704
# Epoch [114/200], Train Loss: 0.0002, Train Accuracy: 1.0000, Test Accuracy: 0.9704
# Epoch [115/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9704
# Epoch [116/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9704
# Epoch [117/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [118/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [119/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9709
# Epoch [120/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [121/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [122/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [123/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [124/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9704
# Epoch [125/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [126/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [127/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [128/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [129/200], Train Loss: 0.0001, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [130/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [131/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [132/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [133/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [134/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [135/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [136/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [137/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [138/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [139/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [140/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9680
# Epoch [141/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9684
# Epoch [142/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9684
# Epoch [143/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9680
# Epoch [144/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [145/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [146/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [147/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [148/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [149/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [150/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9709
# Epoch [151/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9709
# Epoch [152/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9704
# Epoch [153/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9704
# Epoch [154/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [155/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [156/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [157/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9704
# Epoch [158/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [159/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [160/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [161/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [162/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [163/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [164/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [165/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [166/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [167/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [168/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [169/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [170/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [171/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [172/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [173/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [174/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [175/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [176/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [177/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [178/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [179/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [180/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [181/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [182/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [183/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [184/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [185/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [186/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [187/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [188/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [189/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [190/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [191/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [192/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [193/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [194/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [195/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9689
# Epoch [196/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [197/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694
# Epoch [198/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [199/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9699
# Epoch [200/200], Train Loss: 0.0000, Train Accuracy: 1.0000, Test Accuracy: 0.9694

# %%
# Mapping activity names to label numbers
activity_names = ['Walking', 'Walking Upstairs', 'Walking Downstairs', 'Sitting', 'Standing', 'Laying']

# Adjust the labels to start from 0
adjusted_all_labels = [label - 1 for label in all_labels]
adjusted_all_preds = [pred - 1 for pred in all_preds]

# Calculate the confusion matrix
conf_matrix = confusion_matrix(adjusted_all_labels, adjusted_all_preds)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False, xticklabels=activity_names, yticklabels=activity_names, annot_kws={"size": 10})
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')

# Rotate the x-axis tick labels vertically
plt.xticks(rotation=90)

plt.show()
